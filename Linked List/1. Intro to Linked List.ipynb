# %%
class Node:
    def __init__(self, data = 0, next = None):
        self.data = data
        self.next = next

# %%
a = Node(13)
b = Node(14)
a.next = b
c = Node(30)
b.next = c
d = Node(40)
e = Node(50)
c.next = d
d.next = e
print(a.next.next.next)

# %%
# Function to print the LL
def printLL(head):
    while head is not None:
        print(str(head.data) + ' -> ', end ='')
        head = head.next
    print(None)
    return
printLL(a)
# Out:
# 14 -> 30 -> 40 -> 50 -> None

# %%
def takeInput():
        # taking the space seperated input in a list
        inputList = [int(ele) for ele in input().split()]
        head = None
        #Traversing the List ending with -1
        for currData in inputList:
            if currData == -1:
                break
            # Creating a new Node and checking is it's head, if not, traversing the list to find the end and appending element
            newNode = Node(currData)
            if head is None:
                head = newNode
            else:
                curr = head
                while curr.next is not None:
                    curr = curr.next
                curr.next = newNode
        return head
    
def printLL(head):
    while head is not None:
        print(str(head.data) + '->', end = '')
        head = head.next
    print('None')
    return

# %%
head = takeInput()
printLL(head)
# Out:
#  1 2 3 -1
# 1->2->3->None

# %%
# Time COmplexity of Taking Input?
# O(n^2)

# WAP to take input of LL for O(n)

# Check if the LL is PALINDROME to NOT
