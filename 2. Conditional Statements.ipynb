# %% [raw]
# if (CONDITION) :
#     Line 1
#     Line 2
#     Line 3
# else :
#     Line 1

# %% [raw]
# if (CONDITION) :
#     Line 1
# elif (CONDITION) :
#     Line 1
# elif (CONDITION) :
#     Line 1
# elif (CONDITION) :
#     Line 1
# else:
#     line

# %%
a = 5
b = 10
if a > b:
    print(a)
    if a < b:
        print(b)
if a > b:
    print(a)
elif a < b:
    print(b)
    
#3rd Case
if a > b:
    print(a)
elif a < b:
    print(b)
else:
    print("Nothing")
# Out:
# 10
# 10

# %% [raw]
# 1. WAP to check if a person is eligible to vote or not.
# 2. WAP to check whether input num is even or odd.
# 3. WAP to check if the given num is multiple of 5 or not.
# 4. WAP to check if the given num is divisible by 35 or not.
# 5. WAP to print the last digit of a number.
