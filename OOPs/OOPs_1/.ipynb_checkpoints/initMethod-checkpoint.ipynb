# %%
class Student():
    def __init__(self, name, rollNumber):                     # Assigning values to all the objects
        self.name = name
        self.rollNumber = rollNumber

# %%
s1 = Student()
s1.__dict__
# Out:
# {'name': 'Avinash', 'rollNumber': 10}

# %%
s2 = Student()
s2.__dict__
# Out:
# {'name': 'Avinash', 'rollNumber': 10}

# %%
s3 = Student('Saba', 34)

# %%
s3.__dict__
# Out:
# {'name': 'Saba', 'rollNumber': 34}
