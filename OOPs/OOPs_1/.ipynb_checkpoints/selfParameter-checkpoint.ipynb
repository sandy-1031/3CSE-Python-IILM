# %%
class Student:
    def studentDetails():
        pass 
    
s1 = Student()
s1.studentDetails()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-2a015949f871> in <module>
#       4
#       5 s1 = Student()
# ----> 6 s1.studentDetails()
#
# TypeError: studentDetails() takes 0 positional arguments but 1 was given

# %%
# The Last line is interpreted as the following

Student.studentDetails(s1)

# class_name.function(object_name)

# Hence, by default we pass the 'self' attribute in function inside class
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-4d670d1f53bf> in <module>
#       1 # The Last line is interpreted as the following
#       2
# ----> 3 Student.studentDetails(s1)
#       4
#       5 # class_name.function(object_name)
#
# TypeError: studentDetails() takes 0 positional arguments but 1 was given

# %%
class Student:
    passingPercentage = 40
    def studentDetails(self):
        self.name = 'Sandeep'                 # Instance is created. (only accessible till s1 is there)
        print('Name = ', self.name)
        self.percentage = 80
        print('Percentage = ', self.percentage)    # attribute accessible inside this function
        pass
    def isPassed(self):
        if self.percentage > Student.passingPercentage:
            print('Student is Passed')
        else:
            print('Student is Not Passed')
s1 = Student()
s1.studentDetails()
s1.isPassed()
Student.studentDetails(s1)
# Out:
# Name =  Sandeep
# Percentage =  80
# Student is Passed
# Name =  Sandeep
# Percentage =  80

# %% [markdown]
# #### Hence, whatever object is passed will be stored in self.
