# %% [markdown]
# #### Class - Is a template, which tells what kind of data and functionality objects shoud have.
#
# #### Object - is instance of this class
#
# ##### Eg: When FRUIT is a class, its instance will be APPLE, ORANGE, MANGO - which is the object

# %%
class Student:
    pass

# Empty class

# %%
s1 = Student()

# %%
print(type(s1))
# Out:
# <class '__main__.Student'>

# %%
s2 = Student()
s3 = Student()

# %%
print(s2, s3)
# Out:
# <__main__.Student object at 0x000001D1DA88FA90> <__main__.Student object at 0x000001D1DA896C70>

# %% [markdown]
# ### Assigning values to Object

# %%
s1.name = 'Sandeep'

# here name is the attribute

# %%
s2.rollNumber = 22

# %%
s3.name = 'Navdeep'
s3.rollNumber = 23

# %%
s3.rollNumber
# Out:
# 23

# %%
## to see all attributes of object

s3.__dict__
# Out:
# {'name': 'Navdeep', 'rollNumber': 23}

# %%
s2.__dict__
# Out:
# {'rollNumber': 22}

# %%
s1.__dict__

# %%
# has attribute in object

hasattr(s1, 'name')
# Out:
# True

# %%
# get attribut in object
# 3rd attributes is returned when the 2nd one in object is not present   (Default Value)

getattr(s1, 'name')
# Out:
# 'Sandeep'

# %%
getattr(s1, 'rollNumber', '')
# Out:
# ''

# %%
# delete attribute

delattr(s3, 'name')

# %%
s3.__dict__
