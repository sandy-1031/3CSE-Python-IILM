# %% [markdown]
# # Private Variables =  __name
#
# # Private Variables for functions =  __isPassed()
#
# ## Then they will be accessed inside the class only

# %% [markdown]
# # Name Mangling (can access the variable outside the class as well using this concept)
#
# # ._className__variableName
