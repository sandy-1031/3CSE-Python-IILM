# %%
class ZeroDenominatorError(ZeroDivisionError) :
    pass

while True :
    try :
        n = int(input("Enter the Numerator : "))
        d = int(input("Enter the Denominator : "))
        
        if d == 0 :
            raise ZeroDenominatorError('Denominator should not be zero..')
        print("Hii..")
        
        value = n / d
        print(value)
        break
    
    except ValueError:
        print("Numerator and Denominator should be Integer...")
    except ZeroDivisionError :
        print("Division by zero is not allowed ... ")
    except ZeroDenominatorError :
        print("ZeroDenominatorError is raised")
# Out:
# Enter the Numerator : 12
# Enter the Denominator : 0
# Division by zero is not allowed ...
# Enter the Numerator : 12
# Enter the Denominator : 4
# Hii..
# 3.0

# %%
class ZeroDenominatorError(ZeroDivisionError) :
    pass

while True :
    try :
        n = int(input("Enter the Numerator : "))
        d = int(input("Enter the Denominator : "))
        
        if d == 0 :
            raise ZeroDenominatorError('Denominator should not be zero..')
        print("Hii..")
        
        value = n / d
        print(value)
        break
    
    except ValueError:
        print("Numerator and Denominator should be Integer...")
    
    except ZeroDenominatorError :
        print("ZeroDenominatorError is raised")
    
    except ZeroDivisionError :
        print("Division by zero is not allowed ... ")
# Out:
# Enter the Numerator : 12
# Enter the Denominator : 0
# ZeroDenominatorError is raised
# Enter the Numerator : 12
# Enter the Denominator : 5
# Hii..
# 2.4

# %%
# whoever comes first - order matters...

# %%
class ZeroDenominatorError(ZeroDivisionError) :
    pass

while True :
    try :
        n = int(input("Enter the Numerator : "))
        d = int(input("Enter the Denominator : "))
        
        if d == 0 :
            raise ZeroDenominatorError('Denominator should not be zero..')
        print("Hii..")
        
        value = n / d
        print(value)
        break
    
    except ValueError:
        print("Numerator and Denominator should be Integer...")
    
    except  :
        print("ZeroDenominatorError is raised")
    
    except ZeroDivisionError :
        print("Division by zero is not allowed ... ")
# Out:
#   File "<ipython-input-4-8a47a2bd81ff>", line 18
#     print("Numerator and Denominator should be Integer...")
#     ^
# SyntaxError: default 'except:' must be last

# %%
# in above code except: shall come last

# %%
What will be the output of following code?
class ZeroDenominatorError(ZeroDivisionError):
    pass
try:
    a = 10
    b = 0
    if(b==0):
        raise ZeroDenominatorError()
    c = a/b
except ZeroDivisionError:
    print('Zero Division Error occured')
except ZeroDenominatorError:
    print('Zero Denominator Error occured')
    
    
ans - Zero Division Error occured
