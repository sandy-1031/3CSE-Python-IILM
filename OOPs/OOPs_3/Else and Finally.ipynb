# %%
class ZeroDenominatorError(ZeroDivisionError) :
    pass

while True :
    try :
        n = int(input("Enter the Numerator : "))
        d = int(input("Enter the Denominator : "))
        
        if d == 0 :
            raise ZeroDenominatorError('Denominator should not be zero..')
                
        value = n / d
        
    
    except ValueError:
        print("Numerator and Denominator should be Integer...")
    except ZeroDivisionError :
        print("Division by zero is not allowed ... ")
    except ZeroDenominatorError :
        print("ZeroDenominatorError is raised")
    except :
        print("some exception occured")
    else :
        print(value)
        break 
    finally :
        print("It will always be executed damm it ...!!")
# Out:
# Enter the Numerator : 12
# Enter the Denominator : 0
# Division by zero is not allowed ...
# It will always be executed damm it ...!!
# Enter the Numerator : `1
# Numerator and Denominator should be Integer...
# It will always be executed damm it ...!!
# Enter the Numerator : 3
# Enter the Denominator : 3
# 1.0
# It will always be executed damm it ...!!

# %%
What wil be the output of following code?
class ZeroDenominatorError(ZeroDivisionError):
    pass
try:
    a = 10
    b = 0
    if(b==0):
        raise ZeroDenominatorError()
    c = a/b
except ZeroDivisionError:
    print('Zero Division Error occured',end= ‘ ‘)
except ZeroDenominatorError:
    print('Zero Denominator Error occured',end = ‘ ‘)
else:
    print(‘else works’)

    
    ans - Zero Divsion Error occured

# %%
What wil be the output of following code?
class ZeroDenominatorError(ZeroDivisionError):
    pass
try:
    a = 10
    b = 5
    if(b==0):
        raise ZeroDenominatorError()
    c = a/b
except ZeroDivisionError:
    print('Zero Division Error occured',end= ‘ ‘)
except ZeroDenominatorError:
    print('Zero Denominator Error occured',end = ‘ ‘)
else:
    print(‘else works’)
    
    
ans - 
else works

# %%
What wil be the output of following code?
class ZeroDenominatorError(ZeroDivisionError):
    pass
try:
    a = 10
    b = 5
    if(b==0):
        raise ZeroDenominatorError()
    c = a/b
except ZeroDivisionError:
    print('Zero Division Error occured',end= ‘ ‘)
except ZeroDenominatorError:
    print('Zero Denominator Error occured',end = ‘ ‘)
else:
    print(‘else works’,end=' ')
finally:
    print(‘finally works’)

    
    
    
output - 
else works finally works

# %% [markdown]
# ## MORE ABOUT FINALLY

# %%
class ZeroDenominatorError(ZeroDivisionError) :
    pass

while True :
    try :
        n = int(input("Enter the Numerator : "))
        d = int(input("Enter the Denominator : "))
        
        if d == 0 :
            raise ZeroDenominatorError('Denominator should not be zero..')
                
        value = n / d
        
    
    except ValueError:
        print("Numerator and Denominator should be Integer...")
    except ZeroDivisionError :
        print("Division by zero is not allowed ... ")
    except ZeroDenominatorError :
        print("ZeroDenominatorError is raised")
    except :
        print("some exception occured")
    else :
        print(value)
        break 
    finally :
        print(n)
        print(d)
        print("It will always be executed damm it ...!!")
# Out:
# Enter the Numerator : 1
# Enter the Denominator : 0
# Division by zero is not allowed ...
# 1
# 0
# It will always be executed damm it ...!!
# Enter the Numerator : 12
# Enter the Denominator : sd
# Numerator and Denominator should be Integer...
# 12
# 0
# It will always be executed damm it ...!!
# Enter the Numerator : 45
# Enter the Denominator : sdfs
# Numerator and Denominator should be Integer...
# 45
# 0
# It will always be executed damm it ...!!
