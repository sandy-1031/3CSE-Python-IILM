# %% [raw]
#  Every class inherits from object class. Generally three ways
#  1. __new__
#  2. __init__  (generally we overwrite this method)
#  3. __str__

# %%
class Circle:
    def __init__(self, radius):
        self.__radius = radius

# %%
c = Circle(3)
print(c)

# %%
class Circle:
    def __init__(self, radius):
        self.__radius = radius
        
    def __str__(self):
        return 'This is a circle class which takes radius as an input'

# %%
c = Circle(4)
print(c)
# Out:
# This is a circle class which takes radius as an input
