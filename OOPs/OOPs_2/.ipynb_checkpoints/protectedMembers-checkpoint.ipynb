# %% [markdown]
# ### can be declared with single underscore, unlike the double underscore in private member declaration

# %%
# making maxSpeed as Protected Member

class Vehicle:

    def __init__(self, color, maxSpeed):
        self.color = color
        self._maxSpeed = maxSpeed
        
    def getMaxSpeed(self):
        return self._maxSpeed
    
    def setMaxSpeed(self, maxSpeed):
        self._maxSpeed = maxSpeed
        
    #def print(self):
        #print('Color =', self.color)
       # print('maxSpeed =', self._maxSpeed)
        
# Class Car will inherit the properties of Class Vehicle

class Car(Vehicle):
    def __init__(self, color, maxSpeed, numGears, isConvertible):
        super().__init__(color, maxSpeed)
        self.numGears = numGears
        self.isConvertible = isConvertible
        
    def print(self):
        #super().print()
        print('Color =', self.color)
        print('maxSpeed =', self._maxSpeed)
        print('numGears = ', self.numGears)
        print('isConvertible =', self.isConvertible)

# %%
c = Car('Yellow', 250, 7, True)
c.print()
# Out:
# Color = Yellow
# maxSpeed = 250
# numGears =  7
# isConvertible = True

# %% [markdown]
# ### There is no such restriction as was in case of private member.
# ### Can also be modified easily, hence no restrictions at all

# %% [markdown]
# ### Python thinks that programmers are sensible, hence the only purpose to declare protected members was to access it as minimal as possible and only in case of Emergency
