# %%
stack = []
stack.append(10)
stack.append(20)
stack.append(30)
print(stack)
# Out:
# [10, 20, 30]

# %%
# POP

stack.pop()
# Out:
# 30

# %%
#PUSH

stack.append(40)
stack
# Out:
# [10, 20, 40]

# %%
# TOP
stack[-1]
# Out:
# 40

# %%
#isEmpty

len(stack) == 0
# Out:
# False

# %%
#SIZE
len(stack)
# Out:
# 3

# %%
# INBUILT STACK
import queue
s = queue.LifoQueue()
s.put(1)
s.put(5)
s.put(15)

while not s.empty():
    print(s.get())
# Out:
# 15
# 5
# 1

# %%
#INBUILT QUEUE
import queue
s = queue.Queue()
s.put(1)
s.put(5)
s.put(15)

while not s.empty():
    print(s.get())
# Out:
# 1
# 5
# 15
