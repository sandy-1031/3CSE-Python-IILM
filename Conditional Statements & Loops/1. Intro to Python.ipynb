# %% [markdown]
# ### Operators in Python

# %%
#Arithematic - 

print("5+2")
print(5**2)
print(5%2)
print(5/2)
a = 5
print(5.0//2)
print(25/4)
print(25//4)
print(25%4)  # gives remainder
a = 6
print(6 * (a**2))  # 2 to the pow 3

#Logical
True
False
None

a = True

if not a:
    print("Logically True")
else:
    print("False")
# Out:
# 5+2
# 25
# 1
# 2.5
# 2.0
# 6.25
# 6
# 1
# 216
# False

# %%
l = "12345"

if "5" not in l:
    print("It is present")
else:
    print("Its not present")
# Out:
# Its not present

# %%
a = 2
a += 1 # a = a + 1
b = a
b += 2
print(a)
print(b)
# Out:
# 3
# 5

# %%
a = 2
print(type(a))

a = "abc"
print(type(a))

a = [1,2,3,4]
print(type(a))

a = 4.56
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'list'>
# <class 'float'>

# %% [raw]
# 1. WAP to calculate SI.
# 2. WAP to calculate area & volume of cube.
# 3. WAP to convert C to F.
#
#
# Mutable and Immutable

# %%
# to find the sum of 2 nums

num1 = 12.0
num2 = 12
sum = num1+num2
print("The sum of 2 numbers is", sum)
